# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #**1. Univariate Analysis for categorical data**#

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic['embark_town'].dtype == 'O'
# Out:
# True

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# ##1. Categorical Data

# %% [markdown]
# -->Count plots

# %% [markdown]
# ##1.Count plot of sex **Column**

# %%
titanic['sex'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
titanic['embarked'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
titanic['class'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
titanic['who'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
titanic['deck'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
titanic['embark_town'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
titanic['alive'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ##2. Pie Chart##

# %%
def pieChart(df,categoricalColumn):
  plotNo = 1
  if df[categoricalColumn].dtype == 'O':
    plt.subplot(1, plotNo, plotNo)
    df[categoricalColumn].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plotNo+=1
    plt.plot()

# %%
titanic['sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='sex'>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic['embarked'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='embarked'>

# %%
titanic['class'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='class'>

# %%
titanic['who'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='who'>

# %%
titanic['deck'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='deck'>

# %%
titanic['alive'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='alive'>

# %%
titanic['alive'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='alive'>

# %% [markdown]
# #**2. Univariate Analysis for numerical Data**#

# %% [markdown]
# ###2.1 Histogram

# %%
plt.hist(titanic['age'], bins=5 )
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(titanic['sex'], bins=5)
# Out:
# (array([577.,   0.,   0.,   0., 314.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(titanic['fare'], bins=5)
# Out:
# (array([838.,  33.,  17.,   0.,   3.]),
#  array([  0.     , 102.46584, 204.93168, 307.39752, 409.86336, 512.3292 ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ###2.2. Distribution plot

# %%
sns.distplot(titanic['age'])
# Out:
# <ipython-input-27-0bbae160b97e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(titanic['survived'])
# Out:
# <ipython-input-28-05c22c7250f6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['survived'])
# <Axes: xlabel='survived', ylabel='Density'>

# %%
sns.distplot(titanic['fare'])
# Out:
# <ipython-input-29-de405d6e17cd>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.distplot(titanic['pclass'])
# Out:
# <ipython-input-30-e0ec041aded4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['pclass'])
# <Axes: xlabel='pclass', ylabel='Density'>

# %% [markdown]
# ###2.3. Boxplot

# %%
sns.boxplot(titanic['age'])
# Out:
# <Axes: >

# %%
titanic['age'].min()
# Out:
# 0.42

# %%
titanic['age'].max()
# Out:
# 80.0

# %%
titanic['age'].skew()
# Out:
# 0.38910778230082704

# %%
sns.boxplot(titanic['fare'])
# Out:
# <Axes: >

# %% [markdown]
# #**3. Bivariate Analysis and multivariate analysis**

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ###3.1. Numerical Vs Numerical

# %%
sns.scatterplot(x=titanic['age'], y=titanic['survived'])
# Out:
# <Axes: xlabel='age', ylabel='survived'>

# %%
sns.scatterplot(x=titanic['survived'], y=titanic['pclass'])
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.scatterplot(x=titanic['pclass'], y=titanic['age'])
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.scatterplot(x=titanic['survived'], y=titanic['parch'])
# Out:
# <Axes: xlabel='survived', ylabel='parch'>

# %%
sns.scatterplot(x=titanic['survived'], y=titanic['fare'])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %% [markdown]
# ###3.2.Bar plot (Numerical- Categorical)

# %%
sns.barplot(x=titanic['pclass'],y=titanic['age'],hue=titanic['sex'])
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(x=titanic['embarked'],y=titanic['age'],hue=titanic['sex'])
# Out:
# <Axes: xlabel='embarked', ylabel='age'>

# %%
sns.barplot(data=titanic, x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ###3.3. BOX plot (N-C)

# %%
sns.boxplot(data=titanic, x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# ###3.4. Distplot (N-C)

# %%
titanic[titanic['survived']==0]['age']
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: age, Length: 549, dtype: float64

# %%
sns.distplot(titanic[titanic['survived']==0]['age'],hist=False, label='Not urvived')
sns.distplot(titanic[titanic['survived']==1]['age'],hist=False, label='Survived')
plt.legend()
# Out:
# <ipython-input-47-e67ac561a785>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==0]['age'],hist=False, label='Not urvived')
# <ipython-input-47-e67ac561a785>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(titanic[titanic['survived']==0]['pclass'],hist=False, label='Not survived')
sns.distplot(titanic[titanic['survived']==1]['pclass'],hist=False, label='Survived')
plt.legend()
# Out:
# <ipython-input-48-7b8b67bde66e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['survived']==0]['pclass'],hist=False, label='Not survived')
# <ipython-input-48-7b8b67bde66e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ###3.5. HeatMap (C-C)

# %%
sns.heatmap(pd.crosstab(titanic['pclass'],titanic['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.heatmap(pd.crosstab(titanic['class'],titanic['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='class'>

# %%
sns.heatmap(pd.crosstab(titanic['sex'],titanic['survived']))
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %% [markdown]
# ###3.6. Cluster Map (C-C)

# %%
sns.clustermap(pd.crosstab(titanic['parch'],titanic['survived']))

# %% [markdown]
# ###3.7. Pairplot

# %%
sns.pairplot(data=titanic,hue='survived')

# %% [markdown]
# ### 3.8. LinePlot (N-N)

# %%
sns.lineplot(data=titanic, x='fare', y='age')
# Out:
# <Axes: xlabel='fare', ylabel='age'>
