# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Data Science Datasets/IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 106           4.9          2.5           4.5          1.7   Iris-virginica
# 97            6.2          2.9           4.3          1.3  Iris-versicolor
# 125           7.2          3.2           6.0          1.8   Iris-virginica
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 59            5.2          2.7           3.9          1.4  Iris-versicolor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #**EDA Analysis**#
# ###**1. Univariate Analysis**###

# %%
sns.countplot(x=df['species'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
sns.countplot(x=df['petal_width'])
# Out:
# <Axes: xlabel='petal_width', ylabel='count'>

# %% [markdown]
# ###**BOX Plot**###

# %%
sns.boxplot(df['sepal_length'])
plt.xlabel('sepal_length')
# Out:
# Text(0.5, 0, 'sepal_length')

# %%
sns.boxplot(df['sepal_width'])
plt.xlabel('sepal_width')
# Out:
# Text(0.5, 0, 'sepal_width')

# %% [markdown]
# ####**Outliers in Sepal Width Using Box Plot**####

# %%
outliers = [data for data in df['sepal_width'] if data < 2.2 or data > 4.0]
outliers
# Out:
# [4.4, 4.1, 4.2, 2.0]

# %%
sns.boxplot(df['petal_length'])
plt.xlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
sns.boxplot(df['petal_width'])
plt.xlabel('petal_width')
# Out:
# Text(0.5, 0, 'petal_width')

# %% [markdown]
# ###**2. Bivariate and Multivariate Analysis**###

# %% [markdown]
# **2. Create a histogram for each feature in the dataset to illustrate the feature distributions.**

# %%
sns.displot(data=df, x="sepal_length", hue='species')

# %%
sns.displot(data=df, x="sepal_width", hue='species')

# %%
sns.displot(data=df, x="petal_length", hue='species')

# %%
sns.displot(data=df, x="sepal_width", hue='species')

# %%
sns.distplot(x=df[df['species']=='Iris-setosa']['petal_width'], label='Iris-setosa')
sns.distplot(x=df[df['species']=='Iris-versicolor']['petal_width'], label='Iris-versicolor')
sns.distplot(x=df[df['species']=='Iris-virginica']['petal_width'], label='Iris-virginica')
plt.xlabel("petal_width")
plt.legend()
plt.show()
# Out:
# <ipython-input-24-46fbb99f244a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[df['species']=='Iris-setosa']['petal_width'], label='Iris-setosa')
# <ipython-input-24-46fbb99f244a>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(x=df[df['species']=='Iris-setosa']['petal_length'], label='Iris-setosa')
sns.distplot(x=df[df['species']=='Iris-versicolor']['petal_length'], label='Iris-versicolor')
sns.distplot(x=df[df['species']=='Iris-virginica']['petal_length'], label='Iris-virginica')
plt.xlabel('petal_length')
plt.legend()
plt.show()
# Out:
# <ipython-input-25-884da1906ff8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[df['species']=='Iris-setosa']['petal_length'], label='Iris-setosa')
# <ipython-input-25-884da1906ff8>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(x=df[df['species']=='Iris-setosa']['sepal_length'], label='Iris-setosa')
sns.distplot(x=df[df['species']=='Iris-versicolor']['sepal_length'], label='Iris-versicolor')
sns.distplot(x=df[df['species']=='Iris-virginica']['sepal_length'], label='Iris-virginica')
plt.xlabel('sepal_length')
plt.legend()
plt.show()
# Out:
# <ipython-input-26-a73ea7e679c1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[df['species']=='Iris-setosa']['sepal_length'], label='Iris-setosa')
# <ipython-input-26-a73ea7e679c1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(x=df[df['species']=='Iris-setosa']['sepal_width'], label='Iris-setosa')
sns.distplot(x=df[df['species']=='Iris-versicolor']['sepal_width'], label='Iris-versicolor')
sns.distplot(x=df[df['species']=='Iris-virginica']['sepal_width'], label='Iris-virginica')
plt.xlabel('sepal_width')
plt.legend()
plt.show()
# Out:
# <ipython-input-27-a5bc81d69786>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[df['species']=='Iris-setosa']['sepal_width'], label='Iris-setosa')
# <ipython-input-27-a5bc81d69786>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <ipython-input-28-fe43fffaf13b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <Axes: >

# %%
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=df, x='petal_length', y='sepal_length', hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.scatterplot(data=df, x='sepal_width', y='sepal_length', hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# #**Train Test Split**#

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,:4], df.iloc[:,-1], test_size=0.2)

# %%
x_train.shape
# Out:
# (120, 4)

# %% [markdown]
# #**Model Training**#

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnbc = GaussianNB()

# %%
gnbc.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
gnbc.predict(x_test)
# Out:
# array(['Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor'], dtype='<U15')

# %%
prediction = {"Actual":y_test, "prediction":gnbc.predict(x_test)}
predictionDf = pd.DataFrame(prediction)
predictionDf
# Out:
#               Actual       prediction
# 22       Iris-setosa      Iris-setosa
# 110   Iris-virginica   Iris-virginica
# 12       Iris-setosa      Iris-setosa
# 27       Iris-setosa      Iris-setosa
# 18       Iris-setosa      Iris-setosa
# 92   Iris-versicolor  Iris-versicolor
# 93   Iris-versicolor  Iris-versicolor
# 91   Iris-versicolor  Iris-versicolor
# 84   Iris-versicolor  Iris-versicolor
# 6        Iris-setosa      Iris-setosa
# 66   Iris-versicolor  Iris-versicolor
# 19       Iris-setosa      Iris-setosa
# 113   Iris-virginica   Iris-virginica
# 111   Iris-virginica   Iris-virginica
# 64   Iris-versicolor  Iris-versicolor
# 80   Iris-versicolor  Iris-versicolor
# 9        Iris-setosa      Iris-setosa
# 28       Iris-setosa      Iris-setosa
# 134   Iris-virginica  Iris-versicolor
# 5        Iris-setosa      Iris-setosa
# 102   Iris-virginica   Iris-virginica
# 4        Iris-setosa      Iris-setosa
# 122   Iris-virginica   Iris-virginica
# 69   Iris-versicolor  Iris-versicolor
# ...

# %% [markdown]
# #**Metrices**#

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %%
predict = gnbc.predict(x_test)

# %% [markdown]
# ###**Accuracy Score**###

# %%
accuracy_score(y_test, predict)
# Out:
# 0.9666666666666667

# %% [markdown]
# ###**Confusion Metrics**###

# %%
confusion_matrix(y_test, predict)
# Out:
# array([[14,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  1,  6]])

# %% [markdown]
# ###**Recall Score**###

# %%
recall_score(y_test, predict, pos_label='positive', average='micro')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1396: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 0.9666666666666667

# %% [markdown]
# ###**Precision Score**###

# %%
precision_score(y_test, predict,pos_label='positive', average='micro')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1396: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 0.9666666666666667

# %% [markdown]
# ###**F1 Score**###

# %%
f1_score(y_test, predict, average='micro', pos_label='positive')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1396: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 0.9666666666666667

# %% [markdown]
# ###**Error Rate**##

# %%
error_rate = 1-accuracy_score(y_test, predict)
error_rate
# Out:
# 0.033333333333333326
